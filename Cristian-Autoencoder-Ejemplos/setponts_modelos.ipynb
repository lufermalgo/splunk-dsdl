# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path_temp='C:/Users/ccollazos/Documents/Summan/dtwcoronahornosacmi/datos/'
df_temp=pd.read_csv(path_temp+'Horno4.csv', low_memory=True, index_col=[0], parse_dates=True)
df_temp.sort_index(inplace=True)
df_temp=df_temp.resample("min").first()
df_temp=df_temp.interpolate(method='time')

# %%
termo_horno=['k1', 'k2', 'k3', 'k4', 's5', 's6', 's7', 's8', 's9', 's10', 's11','s12', 's13', 's14', 's15', 's16', 's17', 's18', 's19', 's20', 'k21','k22', 'k23', 'k24', 'k25', 'k26']

# %%
dfdiff=pd.DataFrame()
for termo in termo_horno:
    dfdiff[termo]=df_temp[termo]-df_temp[termo+'sp']

# %%
dfdiff
# Out:
#                              k1    k2    k3   k4    s5    s6   s7   s8   s9  \
# _time
# 2024-01-01 00:00:00-05:00   5.3  22.9 -14.7 -5.0  -6.2  -1.0  4.0 -5.0  5.0
# 2024-01-01 00:01:00-05:00   6.6  21.2 -14.1 -5.0  -5.8  -1.0  4.4 -5.0  5.3
# 2024-01-01 00:02:00-05:00   6.7  21.4 -13.8 -5.0  -4.9   0.0  3.3 -4.0  5.6
# 2024-01-01 00:03:00-05:00   6.7  22.1 -13.4 -5.0  -4.6   0.0  3.0 -4.0  5.5
# 2024-01-01 00:04:00-05:00   6.3  22.1 -12.9 -6.0  -4.8   0.0  4.0 -6.0  5.7
# ...                         ...   ...   ...  ...   ...   ...  ...  ...  ...
# 2024-12-19 14:29:00-05:00  10.5  25.4 -15.5 -4.0 -11.7  14.0 -0.9  1.0 -2.8
# 2024-12-19 14:30:00-05:00  11.6  23.4 -14.4 -4.0 -11.6  15.0 -1.2  2.0 -2.4
# 2024-12-19 14:31:00-05:00  11.5  19.6 -14.6 -4.0 -11.1  15.0 -1.3  2.0 -2.1
# 2024-12-19 14:32:00-05:00  11.7  16.0 -15.1 -4.0 -10.8  16.0 -1.6  2.0 -2.0
# 2024-12-19 14:33:00-05:00  12.5  14.3 -15.5 -5.0 -10.8  16.0 -1.7  2.0 -1.5
#
# ...
